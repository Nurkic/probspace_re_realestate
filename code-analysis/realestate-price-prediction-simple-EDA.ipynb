# %%
import pandas as pd
import matplotlib.pyplot as plt
import japanize_matplotlib
from IPython.core.display import display, HTML 
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
train = pd.read_csv("../input/train_data.csv")
test = pd.read_csv("../input/test_data.csv")
published = pd.read_csv("../input/published_land_price.csv")

# %%
'''import json

with open("names.json", "r", encoding="utf-8") as f:
     d = json.load(f)

train = train.rename(columns=d)
test = test.rename(columns=d)
'''
# Out:
# 'import json\n\nwith open("names.json", "r", encoding="utf-8") as f:\n     d = json.load(f)\n\ntrain = train.rename(columns=d)\ntest = test.rename(columns=d)\n'

# %% [markdown]
# ## data size

# %%
train.shape, test.shape, published.shape
# Out:
# ((356344, 28), (34844, 27), (2602, 116))

# %%
res1 = pd.read_csv("../output/result_realestate_202008010_01.csv")
res2 = pd.read_csv("../output/result_realestate_20200809_03.csv")
score1 = 0.27
score2 = 0.28

# %%
res_omikuji = pd.DataFrame()
res_omikuji["id"] = res1["id"]
res_omikuji["y"] = res1["y"]*(score1/(score1+score2)) + res2["y"]*(score2/(score1+score2))
display(res1.head())
res_omikuji.head()
res_omikuji.to_csv("res_omikuji.csv", index=False)
# Out:
#    id           y
# 0   0   28.114116
# 1   1   15.869071
# 2   2  222.928913
# 3   3   25.269130
# 4   4   69.260580
#    id           y
# 0   0   28.570348
# 1   1   15.877830
# 2   2  222.401871
# 3   3   25.443916
# 4   4   68.155393

# %% [markdown]
# ## check dtypes

# %%
train.dtypes
# Out:
# id              int64
# 種類             object
# 地域             object
# 市区町村コード         int64
# 都道府県名          object
# 市区町村名          object
# 地区名            object
# 最寄駅：名称         object
# 最寄駅：距離（分）      object
# 間取り            object
# 面積（㎡）          object
# 土地の形状          object
# 間口             object
# 延床面積（㎡）        object
# 建築年            object
# 建物の構造          object
# 用途             object
# 今後の利用目的        object
# 前面道路：方位        object
# 前面道路：種類        object
# 前面道路：幅員（ｍ）    float64
# 都市計画           object
# 建ぺい率（％）       float64
# 容積率（％）        float64
# 取引時点           object
# 改装             object
# 取引の事情等         object
# y             float64
# dtype: object

# %%
published.dtypes
# Out:
# id           int64
# 経度         float64
# 緯度         float64
# 所在地コード       int64
# 用途           int64
#             ...
# 属性移動Ｈ２７      int64
# 属性移動Ｈ２８      int64
# 属性移動Ｈ２９      int64
# 属性移動Ｈ３０      int64
# 属性移動Ｈ３１      int64
# Length: 116, dtype: object

# %% [markdown]
# ## check null

# %%
train.isnull().sum()
# Out:
# id                 0
# 種類                 0
# 地域            159406
# 市区町村コード            0
# 都道府県名              0
# 市区町村名              0
# 地区名              246
# 最寄駅：名称          1551
# 最寄駅：距離（分）      10129
# 間取り           202568
# 面積（㎡）              0
# 土地の形状         159801
# 間口            176081
# 延床面積（㎡）       236201
# 建築年            82841
# 建物の構造          78829
# 用途             81061
# 今後の利用目的       244965
# 前面道路：方位       159830
# 前面道路：種類       161971
# 前面道路：幅員（ｍ）    163065
# 都市計画            3447
# 建ぺい率（％）         5386
# 容積率（％）          5386
# 取引時点               0
# 改装            212071
# 取引の事情等        328208
# y                  0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# id                0
# 種類                0
# 地域            17443
# 市区町村コード           0
# 都道府県名             0
# 市区町村名             0
# 地区名               0
# 最寄駅：名称          137
# 最寄駅：距離（分）       161
# 間取り           18193
# 面積（㎡）             0
# 土地の形状         17447
# 間口            18949
# 延床面積（㎡）       23446
# 建築年            6664
# 建物の構造          6637
# 用途            12134
# 今後の利用目的        2756
# 前面道路：方位       17443
# 前面道路：種類       17668
# 前面道路：幅員（ｍ）    17766
# 都市計画            279
# 建ぺい率（％）         385
# 容積率（％）          385
# 取引時点              0
# 改装            19767
# 取引の事情等        32342
# dtype: int64

# %%
published.isnull().sum()
# Out:
# id         0
# 経度         0
# 緯度         0
# 所在地コード     0
# 用途         0
#           ..
# 属性移動Ｈ２７    0
# 属性移動Ｈ２８    0
# 属性移動Ｈ２９    0
# 属性移動Ｈ３０    0
# 属性移動Ｈ３１    0
# Length: 116, dtype: int64

# %% [markdown]
# ## 種類

# %%
train["種類"].value_counts().plot.bar()
# trainとtestでほぼ分布変わらない印象。
# Out:
# <AxesSubplot:>

# %%
test["種類"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
ts = df.groupby('種類', as_index=False).agg({'y': 'mean'})
#ts = ts.sort_values("種類")
display(plt.plot(ts["種類"], ts["y"]))

# %%
df_tyuko = train[train["種類"]=="中古マンション等"]
df_tyuko["取引時点"].value_counts().plot.bar(figsize=(20, 5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 地域

# %%
train["地域"].value_counts().plot.bar()
# trainとtestでほぼ分布変わらない印象。
# Out:
# <AxesSubplot:>

# %%
test["地域"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 市区町村コード

# %%
train["市区町村コード"].value_counts().plot.bar(figsize=(20, 5))
# 上位はこんな感じ、13112 : 世田谷区、13111 : 大田区、13120 : 練馬区、13121 : 足立区、13115 : 杉並区、都心の住宅街が多い
# Out:
# <AxesSubplot:>

# %%
test["市区町村コード"].value_counts().plot.bar(figsize=(20, 5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 都道府県名

# %%
train["都道府県名"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
test["都道府県名"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 市区町村名

# %%
train["市区町村名"].value_counts().plot.bar(figsize=(20, 5))
# 当たり前だけど市区町村コードと全く同じ情報なので、この特徴量はいらない
# Out:
# <AxesSubplot:>

# %%
test["市区町村名"].value_counts().plot.bar(figsize=(20, 5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 地区名

# %%
train["地区名"].value_counts()
# 値の種類が多いため数で表示、数の多い上位3地区はtrainとtestで変わらない、数の少ない値はまとめる
# Out:
# 本町       3199
# 中央       2108
# 亀戸       1849
# 中町       1611
# 栄町       1493
#          ...
# 梅澤          1
# 神田松永町       1
# 下元郷         1
# 字名組山        1
# 西大泉町        1
# Name: 地区名, Length: 1454, dtype: int64

# %%
test["地区名"].value_counts()
# Out:
# 本町           321
# 中央           226
# 亀戸           183
# 南大井          156
# 西新宿          156
#             ...
# 大字富士山栗原新田      1
# 東篠崎            1
# 元赤坂            1
# 大丹波            1
# 真光寺町           1
# Name: 地区名, Length: 1366, dtype: int64

# %% [markdown]
# ## 最寄駅：名称

# %%
train["最寄駅：名称"].value_counts()
# 数の少ない値はまとめる
# Out:
# 八王子       3315
# 大泉学園      3020
# 新小岩       2927
# 金町        2306
# 三鷹        2182
#           ...
# 東所沢          2
# 遊園地西         1
# 桜ケ丘          1
# 武蔵小杉         1
# 青海(東京)       1
# Name: 最寄駅：名称, Length: 655, dtype: int64

# %%
test["最寄駅：名称"].value_counts()
# Out:
# 八王子        316
# 新小岩        265
# 大森(東京)     231
# 大泉学園       225
# 武蔵小金井      220
#           ...
# 早稲田(都電)      1
# 学習院下         1
# 堀切           1
# 町屋二丁目        1
# 白丸           1
# Name: 最寄駅：名称, Length: 626, dtype: int64

# %% [markdown]
# ## 最寄駅：距離（分）

# %%
train["最寄駅：距離（分）"].value_counts().plot.bar(figsize=(20, 5))
# rainとtestで分布自体はあんま変わらない印象。一部文字列になっている値があるため前処理時に値に変換する
# Out:
# <AxesSubplot:>

# %%
test["最寄駅：距離（分）"].value_counts().plot.bar(figsize=(20, 5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 間取り

# %%
train["間取り"].value_counts().plot.bar(figsize=(20, 5))
# Out:
# <AxesSubplot:>

# %%
test["間取り"].value_counts().plot.bar(figsize=(20, 5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 面積（㎡）

# %%
train["面積（㎡）"].hist()
# 分かりづらい。笑 よって数の方も載せとく
# Out:
# <AxesSubplot:>

# %%
train["面積（㎡）"].value_counts()
# Out:
# 20      25395
# 65      19968
# 70      19695
# 60      19218
# 55      18439
#         ...
# 4500        1
# 4300        1
# 3800        1
# 4000        1
# 4900        1
# Name: 面積（㎡）, Length: 157, dtype: int64

# %%
test["面積（㎡）"].hist()
# Out:
# <AxesSubplot:>

# %%
test["面積（㎡）"].value_counts()
# Out:
# 20      3122
# 65      2034
# 70      1922
# 55      1837
# 60      1831
#         ...
# 2100       1
# 2700       1
# 2800       1
# 3000       1
# 3500       1
# Name: 面積（㎡）, Length: 140, dtype: int64

# %% [markdown]
# ## 土地の形状

# %%
train["土地の形状"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
test["土地の形状"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 間口

# %%
train["間口"].hist()
# 気持ち悪いから数の方も載せる
# Out:
# <AxesSubplot:>

# %%
train["間口"].value_counts()
# Out:
# 8.0     8136
# 10.0    8024
# 7.0     7579
# 9.0     7397
# 6.0     7285
#         ...
# 49.9       1
# 48.1       1
# 41.4       1
# 43.6       1
# 49.6       1
# Name: 間口, Length: 472, dtype: int64

# %%
test["間口"].hist()
# Out:
# <AxesSubplot:>

# %%
test["間口"].value_counts()
# Out:
# 10.0    528
# 9.0     515
# 7.0     477
# 6.0     473
# 8.0     469
#        ...
# 1.4       1
# 27.9      1
# 33.1      1
# 38.4      1
# 24.3      1
# Name: 間口, Length: 359, dtype: int64

# %% [markdown]
# ## 延床面積（㎡）

# %%
train["延床面積（㎡）"].value_counts().plot.bar(figsize=(20, 5))
# これも文字列が混じっているため前処理で数値に変換
# Out:
# <AxesSubplot:>

# %%
test["延床面積（㎡）"].value_counts().plot.bar(figsize=(20, 5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 建築年

# %%
train["建築年"].value_counts().plot.bar(figsize=(20, 5))
# trainに比べtestの方が最近建てられた物件が多い気がする。うまくモデルで考慮したい
# Out:
# <AxesSubplot:>

# %%
test["建築年"].value_counts().plot.bar(figsize=(20, 5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 建物の構造

# %%
train["建物の構造"].value_counts().plot.bar(figsize=(20, 5))
# trainとtestでほぼ分布変わらない印象。
# Out:
# <AxesSubplot:>

# %%
test["建物の構造"].value_counts().plot.bar(figsize=(20, 5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 用途

# %%
train["用途"].value_counts()
# Out:
# 住宅                    245908
# 共同住宅                    9991
# 事務所                     2480
# 住宅、店舗                   2433
# 店舗                      1674
#                        ...
# 共同住宅、工場、事務所、駐車場、店舗         1
# 共同住宅、事務所、倉庫、その他            1
# 工場、倉庫、店舗                   1
# 住宅、工場、事務所、その他              1
# 住宅、共同住宅、事務所、倉庫、駐車場         1
# Name: 用途, Length: 202, dtype: int64

# %%
test["用途"].value_counts()
# Out:
# 住宅                19594
# 共同住宅               1326
# 住宅、店舗               204
# 共同住宅、店舗             162
# 事務所                 156
#                   ...
# 住宅、事務所、その他            1
# 事務所、作業場、倉庫、店舗         1
# 事務所、作業場、倉庫、駐車場        1
# 住宅、工場、倉庫              1
# 駐車場、その他               1
# Name: 用途, Length: 106, dtype: int64

# %% [markdown]
# ## 今後の利用目的

# %%
train["今後の利用目的"].value_counts().plot.bar()
# trainとtestで分布変わらない
# Out:
# <AxesSubplot:>

# %%
test["今後の利用目的"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 前面道路：方位

# %%
train["前面道路：方位"].value_counts().plot.bar()
# trainとtestで分布変わらない
# Out:
# <AxesSubplot:>

# %%
test["前面道路：方位"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 前面道路：種類

# %%
train["前面道路：種類"].value_counts().plot.bar()
# これもほぼ変わらん
# Out:
# <AxesSubplot:>

# %%
test["前面道路：種類"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 前面道路：幅員（ｍ）

# %%
train["前面道路：幅員（ｍ）"].hist()
# Out:
# <AxesSubplot:>

# %%
test["前面道路：幅員（ｍ）"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 都市計画

# %%
train["都市計画"].value_counts().plot.bar()
# ほぼ変わらんのではなかろうか
# Out:
# <AxesSubplot:>

# %%
test["都市計画"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 建ぺい率（％）

# %%
train["建ぺい率（％）"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
test["建ぺい率（％）"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 容積率（％）

# %%
train["容積率（％）"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
test["容積率（％）"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 取引時点

# %%
train["取引時点"].value_counts().plot.bar(figsize=(20, 5))
# trainが3-7年前のデータが多いのに対し、testは1-2年前のデータが多い。
# Out:
# <AxesSubplot:>

# %%
test["取引時点"].value_counts().plot.bar(figsize=(20, 5))
# Out:
# <AxesSubplot:>

# %%
ts = train.groupby('取引時点', as_index=False).agg({'y': 'mean'})
ts = ts.sort_values("取引時点")
display(plt.plot(ts["取引時点"], ts["y"]))
ts
# Out:
#           取引時点           y
# 0   2005年第３四半期   77.409979
# 1   2005年第４四半期   82.610660
# 2   2006年第１四半期   83.418398
# 3   2006年第２四半期   88.208985
# 4   2006年第３四半期  101.248971
# 5   2006年第４四半期   82.179396
# 6   2007年第１四半期  105.886966
# 7   2007年第２四半期   86.189516
# 8   2007年第３四半期   89.394252
# 9   2007年第４四半期   84.475360
# 10  2008年第１四半期  108.617497
# 11  2008年第２四半期   62.333540
# 12  2008年第３四半期   70.672918
# 13  2008年第４四半期   60.914171
# 14  2009年第１四半期   63.367143
# 15  2009年第２四半期   54.574870
# 16  2009年第３四半期   53.632750
# 17  2009年第４四半期   56.427619
# 18  2010年第１四半期   66.266027
# 19  2010年第２四半期   54.031110
# 20  2010年第３四半期   55.105582
# 21  2010年第４四半期   53.486961
# 22  2011年第１四半期   66.723548
# 23  2011年第２四半期   53.259352
# 24  2011年第３四半期   53.242501
# 25  2011年第４四半期   65.286573
# 26  2012年第１四半期   56.212840
# 27  2012年第２四半期   52.794373
# 28  2012年第３四半期   54.540966
# 29  2012年第４四半期   59.808932
# 30  2013年第１四半期   61.588190
# 31  2013年第２四半期   55.629284
# 32  2013年第３四半期   65.757717
# 33  2013年第４四半期   58.872773
# 34  2014年第１四半期   60.243376
# 35  2014年第２四半期   56.496217
# 36  2014年第３四半期   57.154426
# 37  2014年第４四半期   60.978903
# 38  2015年第１四半期   66.386318
# 39  2015年第２四半期   56.912304
# 40  2015年第３四半期   61.077769
# 41  2015年第４四半期   62.728619
# 42  2016年第１四半期   68.524123
# 43  2016年第２四半期   58.081876
# 44  2016年第３四半期   60.907711
# 45  2016年第４四半期   65.826345
# 46  2017年第１四半期   67.968899
# 47  2017年第２四半期   64.902685
# 48  2017年第３四半期   70.716681
# 49  2017年第４四半期   66.988229

# %% [markdown]
# ## 改装

# %%
train["改装"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
test["改装"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 取引の事情等

# %%
train["取引の事情等"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
test["取引の事情等"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## y

# %%
train["y"].hist(range=(0, 2000))
# Out:
# <AxesSubplot:>

# %%
import copy
df = copy.deepcopy(train)
df = df[df["取引時点"] != "2005年第３四半期"]
df = df[df["取引時点"] != "2005年第４四半期"]
df = df[df["取引時点"] != "2006年第１四半期"]
df = df[df["取引時点"] != "2006年第２四半期"]
df = df[df["取引時点"] != "2006年第３四半期"]
df = df[df["取引時点"] != "2006年第４四半期"]
df = df[df["取引時点"] != "2007年第１四半期"]
df = df[df["取引時点"] != "2007年第２四半期"]
df = df[df["取引時点"] != "2007年第３四半期"]
df = df[df["取引時点"] != "2007年第４四半期"]
df = df[df["取引時点"] != "2008年第１四半期"]
df = df[df["取引時点"] != "2008年第２四半期"]
df = df[df["取引時点"] != "2008年第３四半期"]
print(len(train),len(df))
# Out:
# 356344 285931

# %%
ts = df.groupby('取引時点', as_index=False).agg({'y': 'mean'})
ts = ts.sort_values("取引時点")
display(plt.plot(ts["取引時点"], ts["y"]))

# %% [markdown]
# ## train, testとpublishedデータのcolumnの対応づけのmemo

# %% [markdown]
# pair = [("所在地コード","市区町村コード"),("建蔽率","建ぺい率（％）"),("容積率","容積率（％）"),("駅名","最寄駅：名称"), ("地積","面積（㎡）"),("市区町村名","市区町村名"),('前面道路の幅員','前面道路：幅員（ｍ）'), ("前面道路の方位区分","前面道路：方位"),("前面道路区分","前面道路：種類"),("形状区分","土地の形状"), ("用途区分","都市計画")]
# 檜原村：緯度: 35.726822 経度: 139.14886
# 奥多摩町：緯度: 35.809502 経度: 139.096059
